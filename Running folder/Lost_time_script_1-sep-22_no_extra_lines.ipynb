# %%
import os
import pandas as pd 
from bs4 import BeautifulSoup
from lxml import etree
from os import listdir
from os.path import isfile, join

# %%
df = pd.DataFrame()
df_lost_time = pd.DataFrame()
print("this is the main df")
print(df)
print("this is the df for lost time")
print(df_lost_time)
# Out:
# this is the main df
# Empty DataFrame
# Columns: []
# Index: []
# this is the df for lost time
# Empty DataFrame
# Columns: []
# Index: []

# %%
def extractdata(df, filename):

    #opening the the html file
    with open(filename, 'r') as f:

        contents = f.read()
        #this is lxml method to read
        #soup = BeautifulSoup(contents, 'lxml')
        #this is beautiful soup html parser 
        soup = BeautifulSoup(contents, "html.parser")
        dom = etree.HTML(str(soup))

        print("File: " + soup.title.text)

        #assign soup items in to table and rows rows is table body and table rows 
        table = soup.find("table", {"id": "AutoNumber2"})     
        #printing the table
        #print(table)
        rows = table.find("tbody").find_all("tr")
        #neg_length_rows = 0 - len(rows)
        #print("length of rows is:" ,neg_length_rows)


        for row in rows:
            columns = row.find_all("td")
            print("lenght of the column is" , len(columns))
        #for i in range(neg_length_rows,-1):
        #   columns = rows[i].find_all("td")
        #    columns[-1].get_text()
        #    if columns == "LT Summary":
        #        break

            if len(columns) == 16 or len(columns) == 18 or len(columns) == 23:
                continue
            else:
                #iterating over the rows from table
                #this will grab all the columns for each row 
                #the number of columns per each row is
                # 16 if there is no NPT
                # 18 for upper table
                # 11 for lost time table
                # there is an item with 23 elements it is in the middle
                
                #print(getTextFromTag(columns, 18))
                #print(getTextFromTag(columns, lastrow_index)
                try:
                    date = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[2]/table/tbody/tr[3]/td')[0].text
                    wellno = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[3]/table[1]/tbody/tr[2]/td')[0].text
                    rigname = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[4]/table/tbody/tr[2]/td')[0].text
                    Date_and_time = columns[-11].get_text()
                    Time_in_Hrs = columns[-10].get_text()
                    cum_Hrs = columns[-9].get_text()
                    LT_ID = columns[-8].get_text()
                    Parent_LT_ID = columns[-7].get_text()
                    LT_type = columns[-6].get_text()
                    cause = columns[-5].get_text()      
                    object = columns[-4].get_text()
                    company = columns[-3].get_text()
                    depth = columns[-2].get_text()
                    LT_summary = columns[-1].get_text()
                except:
                    date = ""
                    wellno = ""
                    rigname = ""
                    Date_and_time = ""
                    Time_in_Hrs = ""
                    cum_Hrs = ""
                    LT_ID = ""
                    Parent_LT_ID = ""
                    LT_type = ""
                    cause = ""      
                    object = ""
                    company = ""
                    depth = ""
                    LT_summary = ""
                #checking for extra line of information about the depth 
                #and company this will ignore that line. it is un necessary 
                # if company == "Depth":
                #     continue
                    #LT_depth == company
                data = {
                    #this is is to capture lost time
                    "Report Date": date,
                    "Rig Name": rigname,
                    "Well No": wellno, 
                    "Date and Time": Date_and_time,
                    "Time in Hrs": Time_in_Hrs,
                    "Cummulative Hrs" : cum_Hrs,
                    "LT ID": LT_ID,
                    "Parent LT ID":Parent_LT_ID,
                    "LT Type": LT_type,
                    "Cause" : cause,
                    "Object": object,
                    "Company Name": company, 
                    "Depth": depth,
                    "LT Summary": LT_summary,
                    }
                
                df = df.append(data, ignore_index = True)
                
    return df

# %%
#this takes in df and morning reports folder
#it goes through all files in the folder 
#returns data frame 
def readReportsPerDay(df, morningReportFolder):

    mypath = morningReportFolder + "/reports"
    #mypath += "/reports"
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

    count = 1

    for filename in onlyfiles:

        if "DS_Store" in filename:
            continue
        filename = mypath + "/" + filename
        print(str(count) + " " + filename)

        df = extractdata(df, filename)
        count += 1

    return df

# %%
#this funtion will call the reports per day function 
#this is to be used for running the program in folder
#it goes thru the all morning report folders per day inside specific folder 
def runInRunningFolder(df):

    for morningReportFolder in listdir(os.getcwd()):

        if ".ipynb" in morningReportFolder or ".git" in morningReportFolder or ".csv" in morningReportFolder or "DS_Store" in morningReportFolder or ".xlsx" in morningReportFolder or ".json" in morningReportFolder or ".pbix" in morningReportFolder or ".zip" in morningReportFolder:
            continue

        print(morningReportFolder + "\n")

        df = readReportsPerDay(df, morningReportFolder)

    return df

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#this is where we run the code for each item in directory 
#this will list curent working directory and rung th code 

print(os.getcwd())


df = runInRunningFolder(df)

print(df)
# Out:
# \\dir.slb.com\MEA\KSA_Collaborate\SA0048\Completions\Saudi Arabia\13.Aramco Morning Report\2022\02-Feb
# MR 2-01-2022
#
# 1 MR 2-01-2022/reports/088TE QTIF-279.html
# File: 088TE
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 2 MR 2-01-2022/reports/095TE MNIF-221.html
# File: 095TE
# lenght of the column is 16
# 3 MR 2-01-2022/reports/ADC-12 ABQQ-199.html
# File: ADC-12
# lenght of the column is 16
# lenght of the column is 16
# 4 MR 2-01-2022/reports/ADC-14 HRDH-694.html
# File: ADC-14
# lenght of the column is 16
# 5 MR 2-01-2022/reports/ADC-15 HRDH-1915.html
# File: ADC-15
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 6 MR 2-01-2022/reports/ADC-16 JAHM-6.html
# File: ADC-16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 7 MR 2-01-2022/reports/ADC-17 ZULF-1210.html
# File: ADC-17
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 8 MR 2-01-2022/reports/ADC-21 MHWZ-125104.html
# File: ADC-21
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 9 MR 2-01-2022/reports/ADC-23 RMLH-15.html
# File: ADC-23
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 10 MR 2-01-2022/reports/ADC-29 ABMK-4.html
# File: ADC-29
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 11 MR 2-01-2022/reports/ADC-31 SDGM-1163.html
# File: ADC-31
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 12 MR 2-01-2022/reports/ADC-32 SDGM-1139.html
# File: ADC-32
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 13 MR 2-01-2022/reports/ADC-34 UTMN-2317.html
# File: ADC-34
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 14 MR 2-01-2022/reports/ADC-35 MAQL-5.html
# File: ADC-35
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 15 MR 2-01-2022/reports/ADC-36 SDGM-1186.html
# File: ADC-36
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 16 MR 2-01-2022/reports/ADC-41L UTMN-3105.html
# File: ADC-41L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 17 MR 2-01-2022/reports/ADC-42L UTMN-2319.html
# File: ADC-42L
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 18 MR 2-01-2022/reports/ADC-43L HWYH-1226.html
# File: ADC-43L
# lenght of the column is 16
# 19 MR 2-01-2022/reports/ADC-45 KHRS-82.html
# File: ADC-45
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 20 MR 2-01-2022/reports/ADC-46L UTMN-3101.html
# File: ADC-46L
# lenght of the column is 16
# 21 MR 2-01-2022/reports/ADC-48 HWYH-1258.html
# File: ADC-48
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 22 MR 2-01-2022/reports/ADC-50 SFNY-1179.html
# File: ADC-50
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 23 MR 2-01-2022/reports/ADC-51 SDGM-1168.html
# File: ADC-51
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 24 MR 2-01-2022/reports/ADC-52 HRDH-2312.html
# File: ADC-52
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 25 MR 2-01-2022/reports/ADC-53L HRDH-1532.html
# File: ADC-53L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 26 MR 2-01-2022/reports/ADC-55L UTMN-3076.html
# File: ADC-55L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 27 MR 2-01-2022/reports/ADC-56L UTMN-3011.html
# File: ADC-56L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 28 MR 2-01-2022/reports/ADC-57L ABHD-620.html
# File: ADC-57L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 29 MR 2-01-2022/reports/ADC-58L ABHD-172.html
# File: ADC-58L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 30 MR 2-01-2022/reports/ADC-59L HRDH-2232.html
# File: ADC-59L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 31 MR 2-01-2022/reports/ADC-60 ABSF-198.html
# File: ADC-60
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 32 MR 2-01-2022/reports/ADC-62L ANDR-764.html
# File: ADC-62L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 33 MR 2-01-2022/reports/ADC-64L UTMN-2310.html
# File: ADC-64L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 34 MR 2-01-2022/reports/ADC-65L HRDH-1980.html
# File: ADC-65L
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 35 MR 2-01-2022/reports/ADC-66L HWYH-1223.html
# File: ADC-66L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 36 MR 2-01-2022/reports/ADC-67L UTMN-3102.html
# File: ADC-67L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 37 MR 2-01-2022/reports/ADC-68L KRSN-705.html
# File: ADC-68L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 38 MR 2-01-2022/reports/ADC-70 BRRI-2230.html
# File: ADC-70
# lenght of the column is 16
# lenght of the column is 16
# 39 MR 2-01-2022/reports/ADES-13 HRDH-1448.html
# File: ADES-13
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 40 MR 2-01-2022/reports/ADES-14 HRDH-476.html
# File: ADES-14
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 41 MR 2-01-2022/reports/ADES-144 UTMN-3041.html
# File: ADES-144
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 42 MR 2-01-2022/reports/ADES-157 HRDH-698.html
# File: ADES-157
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 43 MR 2-01-2022/reports/ADES-158 ABQQ-737.html
# File: ADES-158
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 44 MR 2-01-2022/reports/ADES-173 NJYN-90.html
# File: ADES-173
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 45 MR 2-01-2022/reports/ADES-174 HRDH-2184.html
# File: ADES-174
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 46 MR 2-01-2022/reports/ADES-40 SDGM-139.html
# File: ADES-40
# lenght of the column is 16
# 47 MR 2-01-2022/reports/ADES-798 JFYN-13.html
# File: ADES-798
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 48 MR 2-01-2022/reports/ADES-889 HRDH-1282.html
# File: ADES-889
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 49 MR 2-01-2022/reports/ADM-261 MRJN-138.html
# File: ADM-261
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 50 MR 2-01-2022/reports/ADM-262 MRJN-121.html
# File: ADM-262
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 51 MR 2-01-2022/reports/ADM-266 ZULF-106.html
# File: ADM-266
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 52 MR 2-01-2022/reports/ADM-337 MRJN-900.html
# File: ADM-337
# lenght of the column is 16
# 53 MR 2-01-2022/reports/ADM-339 RBYN-57.html
# File: ADM-339
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 54 MR 2-01-2022/reports/ADM-510 ABSF-223.html
# File: ADM-510
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 55 MR 2-01-2022/reports/ADM-511 MRJN-2011.html
# File: ADM-511
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 56 MR 2-01-2022/reports/ADM-655 BRRI-148.html
# File: ADM-655
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 57 MR 2-01-2022/reports/ADM-656 ABSF-134.html
# File: ADM-656
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 58 MR 2-01-2022/reports/AOD-1 ZULF-695.html
# File: AOD-1
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 59 MR 2-01-2022/reports/AOD-11 SFNY-1502.html
# File: AOD-11
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 60 MR 2-01-2022/reports/AOD-111 MRJN-726.html
# File: AOD-111
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 61 MR 2-01-2022/reports/ARO-2001 BRRI-184.html
# File: ARO-2001
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 62 MR 2-01-2022/reports/ARO-2003 MNIF-735.html
# File: ARO-2003
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 63 MR 2-01-2022/reports/ARO-3001 ZULF-2054.html
# File: ARO-3001
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 64 MR 2-01-2022/reports/ARO-3002 MRJN-813.html
# File: ARO-3002
# lenght of the column is 16
# 65 MR 2-01-2022/reports/ARO-3003 SFNY-1150.html
# File: ARO-3003
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 66 MR 2-01-2022/reports/ARO-3004 KARN-46.html
# File: ARO-3004
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 67 MR 2-01-2022/reports/ARO-4001 MRJN-533.html
# File: ARO-4001
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 68 MR 2-01-2022/reports/BB-84A MRJN-588.html
# File: BB-84A
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 69 MR 2-01-2022/reports/BCTD-3 HRDH-101001.html
# File: BCTD-3
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 70 MR 2-01-2022/reports/BCTD-4 MNJR-7.html
# File: BCTD-4
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 71 MR 2-01-2022/reports/CG-1 ZULF-1203.html
# File: CG-1
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 72 MR 2-01-2022/reports/CR-36A ZULF-2038.html
# File: CR-36A
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 73 MR 2-01-2022/reports/DPS-4 SAHB-34.html
# File: DPS-4
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 74 MR 2-01-2022/reports/DPS-43 SDGM-1187.html
# File: DPS-43
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 75 MR 2-01-2022/reports/DPS-44 UTMN-2335.html
# File: DPS-44
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 76 MR 2-01-2022/reports/DPS-45 UTMN-2280.html
# File: DPS-45
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 77 MR 2-01-2022/reports/DPS-46 SDGM-1177.html
# File: DPS-46
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 78 MR 2-01-2022/reports/DPS-5 HRDH-1909.html
# File: DPS-5
# lenght of the column is 16
# 79 MR 2-01-2022/reports/DPS-74 MDRK-44.html
# File: DPS-74
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 80 MR 2-01-2022/reports/DQ-47 KHRS-369.html
# File: DQ-47
# lenght of the column is 16
# lenght of the column is 16
# 81 MR 2-01-2022/reports/DQ-48 KHRS-384.html
# File: DQ-48
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 82 MR 2-01-2022/reports/DQ-50L HRDH-1492.html
# File: DQ-50L
# lenght of the column is 16
# lenght of the column is 16
# 83 MR 2-01-2022/reports/DQ-57L KHRS-505.html
# File: DQ-57L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 84 MR 2-01-2022/reports/ED-85A SFNY-4060.html
# File: ED-85A
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 85 MR 2-01-2022/reports/ENS-108 SFNY-1560.html
# File: ENS-108
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 86 MR 2-01-2022/reports/ENS-141 MRJN-758.html
# File: ENS-141
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 87 MR 2-01-2022/reports/ENSCO-54 ABSF-13.html
# File: ENSCO-54
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 88 MR 2-01-2022/reports/ENSCO-76 MRJN-2004.html
# File: ENSCO-76
# lenght of the column is 16
# 89 MR 2-01-2022/reports/EXL-IA SFNY-4050.html
# File: EXL-IA
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 90 MR 2-01-2022/reports/EXL-IVA SFNY-4010.html
# File: EXL-IVA
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 91 MR 2-01-2022/reports/HESP1A-1 ANDR-835.html
# File: HESP1A-1
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 92 MR 2-01-2022/reports/HESP1A-2 DHBN-801.html
# File: HESP1A-2
# lenght of the column is 16
# 93 MR 2-01-2022/reports/HI-2 BRRI-462.html
# File: HI-2
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 94 MR 2-01-2022/reports/HI-4 BRRI-780.html
# File: HI-4
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 95 MR 2-01-2022/reports/HI-5 MHRH-60.html
# File: HI-5
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 96 MR 2-01-2022/reports/HI-9 MRJN-228.html
# File: HI-9
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 97 MR 2-01-2022/reports/HWU-1 HZEM-142812.html
# File: HWU-1
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 98 MR 2-01-2022/reports/JACK-202 THRY-816.html
# File: JACK-202
# lenght of the column is 16
# 99 MR 2-01-2022/reports/JACK-203 RGHB-806.html
# File: JACK-203
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 100 MR 2-01-2022/reports/MP-1 LWHH-28.html
# File: MP-1
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 101 MR 2-01-2022/reports/MP-4 LWHH-18.html
# File: MP-4
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 102 MR 2-01-2022/reports/NA-128S ZMLH-5.html
# File: NA-128S
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 45
# lenght of the column is 11
# lenght of the column is 11
# lenght of the column is 11
# lenght of the column is 11
# 103 MR 2-01-2022/reports/NA-18S SDGM-1030.html
# File: NA-18S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 104 MR 2-01-2022/reports/NA-393S HWYH-1087.html
# File: NA-393S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 105 MR 2-01-2022/reports/NBR-115S HRDH-2140.html
# File: NBR-115S
# lenght of the column is 16
# 106 MR 2-01-2022/reports/NBR-16S HMYM-433304.html
# File: NBR-16S
# lenght of the column is 16
# 107 MR 2-01-2022/reports/NBR-196S SDGM-1174.html
# File: NBR-196S
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 108 MR 2-01-2022/reports/NBR-20S JLMS-13.html
# File: NBR-20S
# lenght of the column is 16
# lenght of the column is 16
# 109 MR 2-01-2022/reports/NBR-210S HRDH-1491.html
# File: NBR-210S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 110 MR 2-01-2022/reports/NBR-304S HRDH-2260.html
# File: NBR-304S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 111 MR 2-01-2022/reports/NBR-575S HRDH-2323.html
# File: NBR-575S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 112 MR 2-01-2022/reports/NBR-591S HRDH-1933.html
# File: NBR-591S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 113 MR 2-01-2022/reports/NBR-633S TRYQ-5.html
# File: NBR-633S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 114 MR 2-01-2022/reports/NBR-654S HRDH-1935.html
# File: NBR-654S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 115 MR 2-01-2022/reports/NBR-783S NJYN-89.html
# File: NBR-783S
# lenght of the column is 16
# lenght of the column is 16
# 116 MR 2-01-2022/reports/NBR-797S UTMN-3145.html
# File: NBR-797S
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 117 MR 2-01-2022/reports/NBR-987S ABTL-2.html
# File: NBR-987S
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 118 MR 2-01-2022/reports/PA-218S QTIF-515.html
# File: PA-218S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 119 MR 2-01-2022/reports/PA-326S SAHB-32.html
# File: PA-326S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 120 MR 2-01-2022/reports/PA-529S SHYB-907.html
# File: PA-529S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 121 MR 2-01-2022/reports/PA-604S HRDH-1392.html
# File: PA-604S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 122 MR 2-01-2022/reports/PA-622S ZHRA-1.html
# File: PA-622S
# lenght of the column is 16
# 123 MR 2-01-2022/reports/PA-70S MDRK-64.html
# File: PA-70S
# lenght of the column is 16
# 124 MR 2-01-2022/reports/PA-785S QTIF-24.html
# File: PA-785S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 125 MR 2-01-2022/reports/PA-861S HRDH-1332.html
# File: PA-861S
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 126 MR 2-01-2022/reports/PA-866S UBYL-4.html
# File: PA-866S
# lenght of the column is 16
# lenght of the column is 16
# 127 MR 2-01-2022/reports/PN-7 MRJN-778.html
# File: PN-7
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 128 MR 2-01-2022/reports/PN-9 MRJN-94.html
# File: PN-9
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 129 MR 2-01-2022/reports/RBP-50A HSBH-58.html
# File: RBP-50A
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 130 MR 2-01-2022/reports/RM-74A KARN-61.html
# File: RM-74A
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 131 MR 2-01-2022/reports/RPKU-2 ABQQ-133.html
# File: RPKU-2
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 132 MR 2-01-2022/reports/RPKU-2 ABQQ-298.html
# File: RPKU-2
# lenght of the column is 16
# 133 MR 2-01-2022/reports/SA5898 HRDH-2101.html
# File: SA5898
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 134 MR 2-01-2022/reports/SCTD-1 UTMN-3070.html
# File: SCTD-1
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 135 MR 2-01-2022/reports/SCTD-2 UTMN-1889.html
# File: SCTD-2
# lenght of the column is 16
# lenght of the column is 16
# 136 MR 2-01-2022/reports/SDA MRJN-732.html
# File: SDA
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 137 MR 2-01-2022/reports/SIN30L MZLJ-680.html
# File: SIN30L
# lenght of the column is 16
# 138 MR 2-01-2022/reports/SINO-10 UMTW-1.html
# File: SINO-10
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 139 MR 2-01-2022/reports/SINO-11 UMJF-17.html
# File: SINO-11
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 140 MR 2-01-2022/reports/SINO-12L HRDH-447.html
# File: SINO-12L
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 141 MR 2-01-2022/reports/SINO-15L ANDR-99.html
# File: SINO-15L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 142 MR 2-01-2022/reports/SINO-16 FDHL-104.html
# File: SINO-16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 143 MR 2-01-2022/reports/SINO-18 ADHN-10.html
# File: SINO-18
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 144 MR 2-01-2022/reports/SINO-19L UTMN-633.html
# File: SINO-19L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 145 MR 2-01-2022/reports/SINO-1L KHRS-548.html
# File: SINO-1L
# lenght of the column is 16
# 146 MR 2-01-2022/reports/SINO-22 BRRI-381.html
# File: SINO-22
# lenght of the column is 16
# lenght of the column is 16
# 147 MR 2-01-2022/reports/SINO-25 MNIF-143.html
# File: SINO-25
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 148 MR 2-01-2022/reports/SINO-27N HRDH-485.html
# File: SINO-27N
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 149 MR 2-01-2022/reports/SINO-28L SHYB-243.html
# File: SINO-28L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 150 MR 2-01-2022/reports/SINO-32L SHYB-535.html
# File: SINO-32L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 151 MR 2-01-2022/reports/SINO-33L KHRS-365.html
# File: SINO-33L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 152 MR 2-01-2022/reports/SINO-36L SDGM-452.html
# File: SINO-36L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 153 MR 2-01-2022/reports/SINO-37L HWYH-347.html
# File: SINO-37L
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# ...
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 177 MR 2-07-2022/reports/SND-2007 ADHN-370100.html
# File: SND-2007
# lenght of the column is 16
# 178 MR 2-07-2022/reports/SND-2008 HWYH-947.html
# File: SND-2008
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 179 MR 2-07-2022/reports/SND-2009 NJYN-81.html
# File: SND-2009
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 180 MR 2-07-2022/reports/SND-3001 MHWZ-167102.html
# File: SND-3001
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 181 MR 2-07-2022/reports/SND-3002 DMMM-602.html
# File: SND-3002
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 182 MR 2-07-2022/reports/SND-3003 HRDH-2345.html
# File: SND-3003
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 183 MR 2-07-2022/reports/SNF036 MRJN-901.html
# File: SNF036
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 184 MR 2-07-2022/reports/SNT-025 SFNY-520.html
# File: SNT-025
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 185 MR 2-07-2022/reports/SP-101 ABQQ-292.html
# File: SP-101
# lenght of the column is 16
# 186 MR 2-07-2022/reports/SP-103 KRSN-48.html
# File: SP-103
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 187 MR 2-07-2022/reports/SP-105 SHRR-818.html
# File: SP-105
# lenght of the column is 16
# lenght of the column is 16
# 188 MR 2-07-2022/reports/SP-106 HRDH-3542.html
# File: SP-106
# lenght of the column is 16
# 189 MR 2-07-2022/reports/SP-110 HWYH-127.html
# File: SP-110
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 190 MR 2-07-2022/reports/SP-120 MNIF-189.html
# File: SP-120
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 191 MR 2-07-2022/reports/SP-122 SDGM-726.html
# File: SP-122
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 192 MR 2-07-2022/reports/SP-124 ABHD-6.html
# File: SP-124
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 193 MR 2-07-2022/reports/SP-160 HWTH-79.html
# File: SP-160
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 194 MR 2-07-2022/reports/SP-161 HWYH-2551.html
# File: SP-161
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 195 MR 2-07-2022/reports/SP-229 SFNY-720.html
# File: SP-229
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 196 MR 2-07-2022/reports/SP-257 HZEM-141214.html
# File: SP-257
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 197 MR 2-07-2022/reports/SP-258 HZEM-160602.html
# File: SP-258
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 198 MR 2-07-2022/reports/SP-259 HZEM-160812.html
# File: SP-259
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 199 MR 2-07-2022/reports/SP-260 HZEM-141612.html
# File: SP-260
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 200 MR 2-07-2022/reports/SP-261 HZEM-162104.html
# File: SP-261
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 201 MR 2-07-2022/reports/SP-262 HZEM-141402.html
# File: SP-262
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 202 MR 2-07-2022/reports/SP-276 KIDN-829.html
# File: SP-276
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 203 MR 2-07-2022/reports/SP-306 MNIF-865.html
# File: SP-306
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 204 MR 2-07-2022/reports/SP-58 MDRK-53.html
# File: SP-58
# lenght of the column is 16
# lenght of the column is 16
# 205 MR 2-07-2022/reports/SSA-101 BRRI-1145.html
# File: SSA-101
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 206 MR 2-07-2022/reports/SSA-102 QTIF-699.html
# File: SSA-102
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 207 MR 2-07-2022/reports/SSA-201 HRDH-2176.html
# File: SSA-201
# lenght of the column is 16
# 208 MR 2-07-2022/reports/SSA-202 QTIF-674.html
# File: SSA-202
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 209 MR 2-07-2022/reports/SSA-29 QTIF-381.html
# File: SSA-29
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 210 MR 2-07-2022/reports/SSA-302 HRDH-1954.html
# File: SSA-302
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 211 MR 2-07-2022/reports/SSA-46 JAHM-5.html
# File: SSA-46
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 212 MR 2-07-2022/reports/SSA-51 MNIF-259.html
# File: SSA-51
# lenght of the column is 16
# 213 MR 2-07-2022/reports/SSA-5820 SDGM-1215.html
# File: SSA-5820
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 214 MR 2-07-2022/reports/SSA-5859 HWYH-1265.html
# File: SSA-5859
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 215 MR 2-07-2022/reports/SSA-5868 HRDH-1946.html
# File: SSA-5868
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 216 MR 2-07-2022/reports/SSA-5891 HRDH-695.html
# File: SSA-5891
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 217 MR 2-07-2022/reports/SSA-5892 SMNH-521700.html
# File: SSA-5892
# lenght of the column is 16
# 218 MR 2-07-2022/reports/SSA-5914 WDYH-80.html
# File: SSA-5914
# lenght of the column is 16
# 219 MR 2-07-2022/reports/SSA-5917 HRDH-2344.html
# File: SSA-5917
# lenght of the column is 16
# 220 MR 2-07-2022/reports/SSA-5962 KHRS-1314.html
# File: SSA-5962
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 221 MR 2-07-2022/reports/SSA-5964 SDGM-1158.html
# File: SSA-5964
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 222 MR 2-07-2022/reports/SSA-5969 UTMN-3195.html
# File: SSA-5969
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 223 MR 2-07-2022/reports/SSA-5970 HWYH-1257.html
# File: SSA-5970
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 224 MR 2-07-2022/reports/SSA-5971 UTMN-2302.html
# File: SSA-5971
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 225 MR 2-07-2022/reports/SSA-5972 NJYN-102.html
# File: SSA-5972
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 226 MR 2-07-2022/reports/SSA-5974 HRDH-1970.html
# File: SSA-5974
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 227 MR 2-07-2022/reports/STY-038 ZULF-2083.html
# File: STY-038
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 228 MR 2-07-2022/reports/T216 ANDR-486.html
# File: T216
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 229 MR 2-07-2022/reports/T217 UTMN-488.html
# File: T217
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 230 MR 2-07-2022/reports/T218 UTMN-471.html
# File: T218
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 231 MR 2-07-2022/reports/T901 JLMN-65.html
# File: T901
# lenght of the column is 16
# 232 MR 2-07-2022/reports/T907 DILM-2.html

# %%
print(df)
# Out:
#     Report Date Rig Name    Well No       Date and Time Time in Hrs  \
# 0    06/21/2022  ADC-43L  UTMN-3118          From  - To         Hrs
# 1    06/21/2022  ADC-43L  UTMN-3118  19 Jun 0245 - 1700          12
# 2    06/21/2022  ADC-55L  UTMN-3171          From  - To         Hrs
# 3    06/21/2022  ADC-55L  UTMN-3171  21 Jun 1415 - 0500       14.25
# 4    06/21/2022  ADC-57L   FDHL-158                   C        COMP
# ..          ...      ...        ...                 ...         ...
# 112  06/21/2022  SSA-101   QTIF-785          From  - To         Hrs
# 113  06/21/2022  SSA-101   QTIF-785  19 Jun 1330 - 0900         2.5
# 114  06/21/2022  SSA-101   QTIF-785  21 Jun 0530 - 0700         1.5
# 115  06/21/2022   WCL-83   MRJN-834          From  - To         Hrs
# 116  06/21/2022   WCL-83   MRJN-834  21 Jun 0530 - 0500        23.5
#
#     Cummulative Hrs    LT ID  Parent LT ID LT Type  Cause  Object  \
# 0          Cum. Hrs    LT ID  Parent LT ID    Type  Cause  Object
# 1             38.25   898513                  WCNT   WCC8      NA
# 2          Cum. Hrs    LT ID  Parent LT ID    Type  Cause  Object
# 3             14.25   898634                  WCNT   WC11      NA
# 4               DTU     DRFT           NSL   16580  16580
# ..              ...      ...           ...     ...    ...     ...
# 112        Cum. Hrs    LT ID  Parent LT ID    Type  Cause  Object
# 113              42   898508                   BHA    FOT     RSS
# 114             1.5   898633                   BHA    FOT     MWD
# 115        Cum. Hrs    LT ID  Parent LT ID    Type  Cause  Object
# 116            23.5   898656                  STUK   STCT    SCRN
#
#     Company Name   Depth                                         LT Summary
# 0        Resp Co   Depth                                         LT Summary
# 1            TK3   10535   OBSERVED INCREASE IN MPD RETURN FLOW. WELL FL...
# 2        Resp Co   Depth                                         LT Summary
# 3            TK3    6243                      OBSERVED INCREASE IN FLOW OUT
# 4                   3267  R/U SLICK LINE & DRIFT. DRIFT WITH 2.347" TO 4...
# ..           ...     ...                                                ...
# 112      Resp Co   Depth                                         LT Summary
# 113          SPS    9795   SPS RSS GIVING WRONG VALUES AT MID WAY TOOL C...
# 114          SDM   16910   NO SDM MWD SIGNAL, SDM TROUBLE SHOOTING TO GE...
# 115      Resp Co   Depth                                         LT Summary
# 116          RIG   11680   WORK ON STUCK COMPLETION STRING BY DIFFERENT ...
#
# [117 rows x 14 columns]

# %%
df.to_excel("LOST TIME TEST 21-jun-22.xlsx")

# %%
def getTextFromTag(columns, index):
    columnText = ""
    try:
        columnText = columns[index].get_text()
    except:
        pass
    return columnText

#this is extract data function
#this function is callled in reports per day function to extract data 
#it reads one file and adds to data frame
#it takes data frame and returns data frame updated per files 
def extractdata(df, filename):

    with open(filename, 'r') as f:

        contents = f.read()
        #this is lxml method to read
        #soup = BeautifulSoup(contents, 'lxml')

        #this is beautiful soup html parser 
        soup = BeautifulSoup(contents, "html.parser")
        dom = etree.HTML(str(soup))

        print("File: " + soup.title.text)
        
        try:
            linerSize = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[2]/td/table/tbody/tr[2]/td[2]/table/tbody/tr[2]/td[1]')[0].text
            date = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[2]/table/tbody/tr[3]/td')[0].text
            wellno = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[3]/table[1]/tbody/tr[2]/td')[0].text
            rigname = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[4]/table/tbody/tr[2]/td')[0].text
        except:
            linerSize = ""
            date = ""
            wellno = ""
            rigname = ""
        
        if linerSize is None:
            linerSize = "None"
        #assign soup items in to table and rows rows is table body and table rows 
        table = soup.find("table", {"id": "AutoNumber2"})     
        #printing the table
        #print(table)
                
        rows = table.find("tbody").find_all("tr")

        for row in rows:
            
            #this will grab all the columns for each row 
            columns = row.find_all("td")
            print(len(columns))
            lateral = getTextFromTag(columns, 4)
            holesize = getTextFromTag(columns, 5)
            majoroperation = getTextFromTag(columns, 7)
            action = getTextFromTag(columns, 8)
            operation = getTextFromTag(columns, 9)
            company = getTextFromTag(columns, 10)
            holeDepthStart = getTextFromTag(columns, 11)
            holeDepthEnd = getTextFromTag(columns, 12)
            eventDepthStart = getTextFromTag(columns, 13)
            eventDepthEnd = getTextFromTag(columns, 14)
            if len(columns) == 16:
                SummaryOfOperation = getTextFromTag(columns, 15)
            else: 
                SummaryOfOperation = getTextFromTag(columns, 17)
            #checking for lost time
                if company == "LT Summary":
                    continue
            data = {
                "Date": date,
                "Well No": wellno,
                "Liner Size": linerSize,
                "Operation": operation,
                "Rig Name": rigname,
                "lateral":lateral,
                "holesize":holesize,
                "majoroperation": majoroperation,
                "action": action,
                "Company Name": company,              
                "Hole Depth Start" : holeDepthStart,
                "Hole Depth End" : holeDepthEnd,
                "Event Depth Start" : eventDepthStart,
                "Event Depth End" : eventDepthEnd,
                "Summarry Of Operation" : SummaryOfOperation       
            }
            
            df = df.append(data, ignore_index = True)

    return df
# Out:
# Empty DataFrame
# Columns: []
# Index: []
