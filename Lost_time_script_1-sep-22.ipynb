# %%
import os
import pandas as pd 
from bs4 import BeautifulSoup
from lxml import etree
from os import listdir
from os.path import isfile, join

# %%
df = pd.DataFrame()
#df_lost_time = pd.DataFrame()
print("this is the main df")
print(df)
print("this is the df for lost time")
#print(df_lost_time)
# Out:
# this is the main df
# Empty DataFrame
# Columns: []
# Index: []
# this is the df for lost time

# %%
def extractdata(df, filename):

    #opening the the html file
    with open(filename, 'r') as f:

        contents = f.read()
        #this is lxml method to read
        #soup = BeautifulSoup(contents, 'lxml')
        #this is beautiful soup html parser 
        soup = BeautifulSoup(contents, "html.parser")
        dom = etree.HTML(str(soup))
        #print("File: " + soup.title.text)
        #assign soup items in to table and rows rows is table body and table rows 
        table = soup.find("table", {"id": "AutoNumber2"})     
        #printing the table
        #print(table)
        rows = table.find("tbody").find_all("tr")
        #neg_length_rows = 0 - len(rows)
        #print("length of rows is:" ,neg_length_rows)


        for row in rows:
            columns = row.find_all("td")
            print("lenght of the column is" , len(columns))
        #for i in range(neg_length_rows,-1):
        #   columns = rows[i].find_all("td")
        #    columns[-1].get_text()
        #    if columns == "LT Summary":
        #        break

            if len(columns) == 16 or len(columns) == 18 or len(columns) == 23:
                continue
            else:
                #iterating over the rows from table
                #this will grab all the columns for each row 
                #the number of columns per each row is
                # 16 if there is no NPT
                # 18 for upper table
                # 11 for lost time table
                # there is an item with 23 elements it is in the middle
                
                #print(getTextFromTag(columns, 18))
                #print(getTextFromTag(columns, lastrow_index)
                try:
                    date = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[2]/table/tbody/tr[3]/td')[0].text
                    wellno = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[3]/table[1]/tbody/tr[2]/td')[0].text
                    rigname = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[4]/table/tbody/tr[2]/td')[0].text
                    Date_and_time = columns[-11].get_text()
                    Time_in_Hrs = columns[-10].get_text()
                    cum_Hrs = columns[-9].get_text()
                    LT_ID = columns[-8].get_text()
                    Parent_LT_ID = columns[-7].get_text()
                    LT_type = columns[-6].get_text()
                    cause = columns[-5].get_text()      
                    object = columns[-4].get_text()
                    company = columns[-3].get_text()
                    depth = columns[-2].get_text()
                    LT_summary = columns[-1].get_text()
                except:
                    date = ""
                    wellno = ""
                    rigname = ""
                    Date_and_time = ""
                    Time_in_Hrs = ""
                    cum_Hrs = ""
                    LT_ID = ""
                    Parent_LT_ID = ""
                    LT_type = ""
                    cause = ""      
                    object = ""
                    company = ""
                    depth = ""
                    LT_summary = ""
                #checking for extra line of information about the depth 
                #and company this will ignore that line. it is un necessary 
                # if company == "Depth":
                #     continue
                    #LT_depth == company
                data = {
                    #this is is to capture lost time
                    "Report Date": date,
                    "Rig Name": rigname,
                    "Well No": wellno, 
                    "Date and Time": Date_and_time,
                    "Time in Hrs": Time_in_Hrs,
                    "Cummulative Hrs" : cum_Hrs,
                    "LT ID": LT_ID,
                    "Parent LT ID":Parent_LT_ID,
                    "LT Type": LT_type,
                    "Cause" : cause,
                    "Object": object,
                    "Company Name": company, 
                    "Depth": depth,
                    "LT Summary": LT_summary,
                    }
                
                df = df.append(data, ignore_index = True)
                
    return df

# %%
#this takes in df and morning reports folder
#it goes through all files in the folder 
#returns data frame 
def readReportsPerDay(df, morningReportFolder):

    mypath = morningReportFolder + "/reports"
    #mypath += "/reports"
    onlyfiles = [f for f in listdir(mypath) if isfile(join(mypath, f))]

    count = 1

    for filename in onlyfiles:

        if "DS_Store" in filename:
            continue
        filename = mypath + "/" + filename
        print(str(count) + " " + filename)

        df = extractdata(df, filename)
        count += 1

    return df

# %%
#this funtion will call the reports per day function 
#this is to be used for running the program in folder
#it goes thru the all morning report folders per day inside specific folder 
def runInRunningFolder(df):

    for morningReportFolder in listdir(os.getcwd()):

        if ".ipynb" in morningReportFolder or ".git" in morningReportFolder or ".csv" in morningReportFolder or "DS_Store" in morningReportFolder or ".xlsx" in morningReportFolder or ".json" in morningReportFolder or ".pbix" in morningReportFolder or ".zip" in morningReportFolder:
            continue

        print(morningReportFolder + "\n")

        df = readReportsPerDay(df, morningReportFolder)

    return df

# %%
#this is where we run the code for each item in directory 
#this will list curent working directory and rung th code 

print(os.getcwd())


df = runInRunningFolder(df)

print(df)
# Out:
# e:\Morning report Data\2022\06-Jun
# MR 06-01-2022
#
# 1 MR 06-01-2022/reports/088TE-QTIF-330.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 2 MR 06-01-2022/reports/910TE-DMMM-525.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 3 MR 06-01-2022/reports/ADC-12-ABQQ-276.html
# lenght of the column is 16
# lenght of the column is 16
# 4 MR 06-01-2022/reports/ADC-14-HRDH-612.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 5 MR 06-01-2022/reports/ADC-15-HWYH-1140.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 6 MR 06-01-2022/reports/ADC-16-JAHM-6.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 7 MR 06-01-2022/reports/ADC-17-ZULF-1215.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 8 MR 06-01-2022/reports/ADC-21-MZLJ-155201.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 9 MR 06-01-2022/reports/ADC-23-KIDN-23.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 10 MR 06-01-2022/reports/ADC-29-NYYM-102.html
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 11 MR 06-01-2022/reports/ADC-31-SDGM-1181.html
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 34
# lenght of the column is 11
# lenght of the column is 11
# lenght of the column is 11
# 12 MR 06-01-2022/reports/ADC-32-SDGM-1228.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 13 MR 06-01-2022/reports/ADC-34-UTMN-2316.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 14 MR 06-01-2022/reports/ADC-35-MAQL-5.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 15 MR 06-01-2022/reports/ADC-36-SDGM-1236.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 16 MR 06-01-2022/reports/ADC-41L-UTMN-3142.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 17 MR 06-01-2022/reports/ADC-42L-UTMN-2327.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 18 MR 06-01-2022/reports/ADC-43L-UTMN-3118.html
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 19 MR 06-01-2022/reports/ADC-45-KHRS-465.html
# lenght of the column is 16
# 20 MR 06-01-2022/reports/ADC-46L-UTMN-3154.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 21 MR 06-01-2022/reports/ADC-48-HWYH-1256.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 22 MR 06-01-2022/reports/ADC-49-HRDH-2128.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 23 MR 06-01-2022/reports/ADC-50-SFNY-1176.html
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 24 MR 06-01-2022/reports/ADC-51-SDGM-1245.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 25 MR 06-01-2022/reports/ADC-52-SDGM-1185.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
#
html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 230 MR 06-30-2022/reports/SSA-5971-HRDH-2247.html
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 231 MR 06-30-2022/reports/SSA-5972-SHDN-19.html
# lenght of the column is 16
# lenght of the column is 16
# 232 MR 06-30-2022/reports/SSA-5974-HRDH-1970.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 233 MR 06-30-2022/reports/STY-038-ZULF-2086.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 234 MR 06-30-2022/reports/T216-ANDR-338.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 235 MR 06-30-2022/reports/T217-UTMN-306.html
# lenght of the column is 16
# 236 MR 06-30-2022/reports/T217-UTMN-475.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 237 MR 06-30-2022/reports/T218-UTMN-1281.html
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 18
# lenght of the column is 23
# lenght of the column is 11
# lenght of the column is 11
# 238 MR 06-30-2022/reports/T901-JLMN-47.html
# lenght of the column is 16
# lenght of the column is 16
# 239 MR 06-30-2022/reports/T902-MHWZ-906.html
# lenght of the column is 16
# 240 MR 06-30-2022/reports/T907-SRYN-1.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 241 MR 06-30-2022/reports/T914-UTMN-463.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 242 MR 06-30-2022/reports/V140A-SFNY-1830.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 243 MR 06-30-2022/reports/WCL-83-MRJN-834.html
# lenght of the column is 16
# 244 MR 06-30-2022/reports/ZPEC-1-KHRM-805.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# 245 MR 06-30-2022/reports/ZPEC-2-HIRN-801.html
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
# lenght of the column is 16
#       Cause Company Name Cummulative Hrs       Date and Time   Depth    LT ID  \
# 0     Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 1       FOT          BHI            21.5  31 May 0800 - 0500    7892   897252
# 2      FPMP          RIG               2  01 Jun 0300 - 0500   11349   897313
# 3     Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 4      FPMP          RIG               7  31 May 1000 - 1500   10730   897255
# ...     ...          ...             ...                 ...     ...      ...
# 2691   HFFT          SJC            4.25  29 Jun 2100 - 0500   10206   899073
# 2692  Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 2693    FOT          RIG             1.5  30 Jun 0200 - 0330   12573   899081
# 2694  Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 2695   UDWL          WDS            11.5  30 Jun 1730 - 0500    9692   899061
#
#                                              LT Summary LT Type  Object  \
# 0                                            LT Summary    Type  Object
# 1      BHI DIR DRILLING UNABLE TO CATCH THE PLAN WHI...     BHA    MMOT
# 2              LEAKING ON MANIFOLD MODULE SEAL PUMP N#2      RR    MPMP
# 3                                            LT Summary    Type  Object
# 4                                     MUD PUMP FAILURE.      RR    MPMP
# ...                                                 ...     ...     ...
# 2691   AFTER 4 1/2" LINER CEMENT JOB, TRIED TO REVER...     CMT      NA
# 2692                                         LT Summary    Type  Object
# 2693                                TOP DRIVE DIES OUT.      RR     TDS
# 2694                                         LT Summary    Type  Object
# 2695                  WDS DD UNABLE TO FOLLOW GOC PLAN.      DD     RSS
#
#       Parent LT ID Report Date  Rig Name Time in Hrs    Well No
# 0     Parent LT ID  06/01/2022    ADC-29         Hrs   NYYM-102
# 1                   06/01/2022    ADC-29        12.5   NYYM-102
# 2                   06/01/2022    ADC-31           2  SDGM-1181
# 3     Parent LT ID  06/01/2022    ADC-31         Hrs  SDGM-1181
# 4                   06/01/2022    ADC-31           2  SDGM-1181
# ...            ...         ...       ...         ...        ...
# 2691                06/30/2022  SSA-5964        3.25  HRDH-1383
# 2692  Parent LT ID  06/30/2022  SSA-5971         Hrs  HRDH-2247
# 2693                06/30/2022  SSA-5971         1.5  HRDH-2247
# 2694  Parent LT ID  06/30/2022      T218         Hrs  UTMN-1281
# 2695                06/30/2022      T218        11.5  UTMN-1281
#
# [2696 rows x 14 columns]

# %%
print(df)
# Out:
#       Cause Company Name Cummulative Hrs       Date and Time   Depth    LT ID  \
# 0     Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 1       FOT          BHI            21.5  31 May 0800 - 0500    7892   897252
# 2      FPMP          RIG               2  01 Jun 0300 - 0500   11349   897313
# 3     Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 4      FPMP          RIG               7  31 May 1000 - 1500   10730   897255
# ...     ...          ...             ...                 ...     ...      ...
# 2691   HFFT          SJC            4.25  29 Jun 2100 - 0500   10206   899073
# 2692  Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 2693    FOT          RIG             1.5  30 Jun 0200 - 0330   12573   899081
# 2694  Cause      Resp Co        Cum. Hrs          From  - To   Depth    LT ID
# 2695   UDWL          WDS            11.5  30 Jun 1730 - 0500    9692   899061
#
#                                              LT Summary LT Type  Object  \
# 0                                            LT Summary    Type  Object
# 1      BHI DIR DRILLING UNABLE TO CATCH THE PLAN WHI...     BHA    MMOT
# 2              LEAKING ON MANIFOLD MODULE SEAL PUMP N#2      RR    MPMP
# 3                                            LT Summary    Type  Object
# 4                                     MUD PUMP FAILURE.      RR    MPMP
# ...                                                 ...     ...     ...
# 2691   AFTER 4 1/2" LINER CEMENT JOB, TRIED TO REVER...     CMT      NA
# 2692                                         LT Summary    Type  Object
# 2693                                TOP DRIVE DIES OUT.      RR     TDS
# 2694                                         LT Summary    Type  Object
# 2695                  WDS DD UNABLE TO FOLLOW GOC PLAN.      DD     RSS
#
#       Parent LT ID Report Date  Rig Name Time in Hrs    Well No
# 0     Parent LT ID  06/01/2022    ADC-29         Hrs   NYYM-102
# 1                   06/01/2022    ADC-29        12.5   NYYM-102
# 2                   06/01/2022    ADC-31           2  SDGM-1181
# 3     Parent LT ID  06/01/2022    ADC-31         Hrs  SDGM-1181
# 4                   06/01/2022    ADC-31           2  SDGM-1181
# ...            ...         ...       ...         ...        ...
# 2691                06/30/2022  SSA-5964        3.25  HRDH-1383
# 2692  Parent LT ID  06/30/2022  SSA-5971         Hrs  HRDH-2247
# 2693                06/30/2022  SSA-5971         1.5  HRDH-2247
# 2694  Parent LT ID  06/30/2022      T218         Hrs  UTMN-1281
# 2695                06/30/2022      T218        11.5  UTMN-1281
#
# [2696 rows x 14 columns]

# %%
df.to_excel("LOST TIME TEST_jun-22.xlsx")

# %%
#This module is to iterate over columns of each row and check for value
#if the value is a match skip the row.

for row in rows:
            
        #this will grab all the columns for each row 
        columns = row.find_all("td")
        print(len(columns))

        for col in columns:
            if col[0].get_text == "Lost Time Details":
                continue
            else:

                lateral = getTextFromTag(columns, 4)
                holesize = getTextFromTag(columns, 5)
                majoroperation = getTextFromTag(columns, 7)
                action = getTextFromTag(columns, 8)
                operation = getTextFromTag(columns, 9)
                company = getTextFromTag(columns, 10)
                holeDepthStart = getTextFromTag(columns, 11)
                holeDepthEnd = getTextFromTag(columns, 12)
                eventDepthStart = getTextFromTag(columns, 13)
                eventDepthEnd = getTextFromTag(columns, 14)
                if len(columns) == 16:
                    SummaryOfOperation = getTextFromTag(columns, 15)
                else: 
                    SummaryOfOperation = getTextFromTag(columns, 17)
                #checking for lost time
                    if company == "LT Summary":
                        continue
                data = {
                    "Date": date,
                    "Well No": wellno,
                    "Liner Size": linerSize,
                    "Operation": operation,
                    "Rig Name": rigname,
                    "lateral":lateral,
                    "holesize":holesize,
                    "majoroperation": majoroperation,
                    "action": action,
                    "Company Name": company,              
                    "Hole Depth Start" : holeDepthStart,
                    "Hole Depth End" : holeDepthEnd,
                    "Event Depth Start" : eventDepthStart,
                    "Event Depth End" : eventDepthEnd,
                    "Summarry Of Operation" : SummaryOfOperation       
                }
                
                df = df.append(data, ignore_index = True)

# %% [markdown]
# Logger Module

# %%
def extractdata(df, filename):
    LT = ""


    #opening the the html file
    with open(filename, 'r') as f:

        contents = f.read()
        #this is lxml method to read
        #soup = BeautifulSoup(contents, 'lxml')
        #this is beautiful soup html parser 
        soup = BeautifulSoup(contents, "html.parser")
        dom = etree.HTML(str(soup))
        #print("File: " + soup.title.text)
        #assign soup items in to table and rows rows is table body and table rows 
        table = soup.find("table", {"id": "AutoNumber2"})     
        #printing the table
        #print(table)
        rows = table.find("tbody").find_all("tr")
        #neg_length_rows = 0 - len(rows)
        #print("length of rows is:" ,neg_length_rows)


        for row in rows:
            columns = row.find_all("td")
            print("lenght of the column is" , len(columns))
        #for i in range(neg_length_rows,-1):
        #   columns = rows[i].find_all("td")
        #    columns[-1].get_text()
        #    if columns == "LT Summary":
        #        break

            if len(columns) == 16:
                LT = False
            elif len(columns) == 18:
                LT = True
            else:
                #iterating over the rows from table
                #this will grab all the columns for each row 
                #the number of columns per each row is
                # 16 if there is no NPT
                # 18 for upper table
                # 11 for lost time table
                # there is an item with 23 elements it is in the middle
                
                #print(getTextFromTag(columns, 18))
                #print(getTextFromTag(columns, lastrow_index)
                try:
                    date = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[2]/table/tbody/tr[3]/td')[0].text
                    wellno = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[3]/table[1]/tbody/tr[2]/td')[0].text
                    rigname = dom.xpath('//*[@id="AutoNumber1"]/thead/tr[1]/td/table/tbody/tr[1]/td[4]/table/tbody/tr[2]/td')[0].text
                    col_length = len(columns)
               except:    
                    date = ""
                    wellno = ""
                    rigname = ""
                    Date_and_time = ""
                    
                data = {
                    #this is is to capture lost time
                    "Report Date": date,
                    "Rig Name": rigname,
                    "Well No": wellno, 
                    "Column Lenght:": Date_and_time,
    
                    }
                
                df = df.append(data, ignore_index = True)
                
    return df
